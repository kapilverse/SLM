# %%
import torch
print(torch.cuda.is_available(), torch.cuda.get_device_name(0))
# Out:
# True Tesla T4

# %%
# !git clone https://github.com/kapilverse/GQA_MHA.git
# %cd GQA_MHA
# Out:
# Cloning into 'GQA_MHA'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 9.23 KiB | 4.61 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /kaggle/working/GQA_MHA

# %%
# !pip install -q tiktoken datasets

# %%
# !python prepare_tinystories.py --output data/tinystories.txt --num-stories 500000
# Out:
# README.md: 1.06kB [00:00, 2.56MB/s]
# ...
# data/train-00000-of-00004-2d5a1467fff108(…): 100%|█| 249M/249M [00:07<00:00, 32.
# data/train-00001-of-00004-5852b56a2bd28f(…): 100%|█| 248M/248M [00:04<00:00, 58.
# data/train-00002-of-00004-a26307300439e9(…): 100%|█| 246M/246M [00:04<00:00, 58.
# data/train-00003-of-00004-d243063613e5a0(…): 100%|█| 248M/248M [00:04<00:00, 58.
# data/validation-00000-of-00001-869c898b5(…): 100%|█| 9.99M/9.99M [00:01<00:00, 9
# Generating train split: 100%|█| 2119719/2119719 [00:06<00:00, 336268.89 examples
# Generating validation split: 100%|█| 21990/21990 [00:00<00:00, 368069.70 example
# Writing 500000 stories to data/tinystories.txt ...
# Done.

# %%
# !python run_experiment.py --data-path data/tinystories.txt --max-steps 30000 --out /kaggle/working/comparison_results.json
# Out:
# [gqa] Using device: cuda
# [gqa] step    250 | train_loss 5.9321 | val_loss 6.0406 | 34.8s
# [gqa] step    500 | train_loss 5.6339 | val_loss 5.5616 | 58.8s
# [gqa] step    750 | train_loss 4.9525 | val_loss 4.8865 | 84.0s
# [gqa] step   1000 | train_loss 4.4143 | val_loss 4.4664 | 110.8s
# [gqa] step   1250 | train_loss 4.2593 | val_loss 4.2236 | 140.1s
# [gqa] step   1500 | train_loss 4.1859 | val_loss 4.0105 | 167.0s
# [gqa] step   1750 | train_loss 3.9458 | val_loss 3.8514 | 194.0s
# [gqa] step   2000 | train_loss 3.7490 | val_loss 3.6967 | 221.2s
# [gqa] step   2250 | train_loss 3.7906 | val_loss 3.5926 | 248.7s
# [gqa] step   2500 | train_loss 3.6891 | val_loss 3.5097 | 275.8s
# [gqa] step   2750 | train_loss 3.7705 | val_loss 3.4471 | 303.0s
# [gqa] step   3000 | train_loss 3.5124 | val_loss 3.3562 | 330.2s
# [gqa] step   3250 | train_loss 3.4660 | val_loss 3.3156 | 357.7s
# [gqa] step   3500 | train_loss 3.4063 | val_loss 3.2678 | 384.9s
# ...

# %%
import os 
print(os.listdir("/kaggle/working"))
# Out:
# ['.virtual_documents']

# %%
import os
for root, dirs, files in os.walk("/kaggle/working"):
    for f in files:
        print(os.path.join(root, f))
# Out:
# /kaggle/working/.virtual_documents/__notebook_source__.ipynb

# %%
import subprocess
print(subprocess.run(["find", "/kaggle", "-name", "logs_*.json"], capture_output=True, text=True).stdout)
print(subprocess.run(["find", "/kaggle", "-iname", "*checkpoint*"], capture_output=True, text=True).stdout)
print(subprocess.run(["find", "/", "-maxdepth", "4", "-iname", "GQA_MHA"], capture_output=True, text=True).stdout)
